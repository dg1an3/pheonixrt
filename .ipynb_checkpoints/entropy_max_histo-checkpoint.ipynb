# %%
import matplotlib
import matplotlib.pyplot as plt
import pprint, math, random, inspect, numbers

# %%
def create_img(fn,**kwarg):
    """ creates a square image in the form of a sz*sz element list vector """
    sz = kwarg.get('sz',5)
    img = [float(fn(c,r,**kwarg)) for c in range(sz) for r in range(sz)]
    return img

def uniform_noise(delta=1e-3):    
    return delta*(random.random()-0.5)

def dist_sq(r,c,sz=5):
    return ((r-sz//2)**2 + (c-sz//2)**2)

def quadratic(r,c,sz=5,noise=True):
    scale = float(sz*sz)
    v = dist_sq(r,c,sz)/scale
    return v + (uniform_noise() if noise else 0.)

def gauss(r,c,sz=5,sigma=1.0):
    return math.exp(-dist_sq(r,c,sz)/sigma)

def gabor(r,c,sz=5,sigma=1.0,kx=1.0,ky=0.0,phase=0.0):    
    wave = r*kx + c*ky
    mod = (1.-phase)*math.sin(wave)
    mod += phase*math.cos(wave)
    return mod*math.exp(-dist_sq(r,c,sz)/sigma)

# %matplotlib inline
def show_img(img):
    sz = int(math.ceil(math.sqrt(len(img))))
    plt.imshow([[img[r*sz+c] for c in range(sz)] for r in range(sz)], cmap='gray')
    
quad_img = create_img(quadratic,sz=5)
gauss_img = create_img(gauss,sz=15,sigma=3.0)
gabor_img = create_img(gabor,sz=20,sigma=5.0,phase=1.0)

show_img(gabor_img)

# %%
# %debug "create_img(sz, quadratic, dump=False)"

# %%
def calc_bins(img, width=.1):
    """ calculate the bin boundaries for an image """
    min_px, max_px = min(img), max(img)
    min_bin = math.floor(min_px/width)*width
    bin_count = int((max_px - min_bin)/width)
    inf = 1.e+2
    bins_at = [-inf] + [x*width+min_bin 
                    for x in range(bin_count+2)] + [inf]
    return bins_at

def histogram(img, bins_at, dump=True):
    if dump:
        print("histogram: img (flattened) = "); pprint.pprint(img)
        print("bins_at = "); pprint.pprint(bins_at)
    this_bin = 0.
    for (lower,upper) in zip(bins_at, bins_at[1:]):
        def frac(px):
            return (px-lower)/(upper-lower)
        high_fractions = list(map(frac, filter(lambda px:lower<=px and px<upper, img)))
        if dump:
            print(">>>> \thistogram: for {}: high_fractions = ".format((lower,upper))); pprint.pprint(high_fractions)
        this_bin += sum(map(lambda x:1.-x, high_fractions))
        yield ((lower, upper),this_bin)
        this_bin = sum(high_fractions)

def entropy(bins):
    eps = 1e-10
    bin_sum = sum([count for _,count in bins])
    entropy = 0.0
    for ((lower,upper),count) in bins:
        p = max(count/bin_sum, eps)
        entropy += -p*math.log(p)
    return entropy

def entropy_for_img(img, bins_at, dump=False):
    img_bins = list(histogram(img, bins_at, dump))
    img_entropy = entropy(img_bins)
    if dump:
        print("image_histo ="); pprint.pprint(img_bins)
        print("bin sum = {}".format(sum([count for _,count in img_bins]))) 
        print("img_entropy = {}".format(img_entropy))
    return img_entropy

# create the bins to be reused
bins_at = calc_bins(quad_img)
quad_img_entropy = entropy_for_img(quad_img, bins_at, dump=False)
print("original entropy = {}".format(quad_img_entropy))
# Out:
# original entropy = 1.3871389329478165

# %%
def mean_pixel_value_for_img(img):
    return sum(img)/float(len(img))

def num_grad(fn, v, delta=1.e-1):
    """
    """
    assert(len(v) > 0)
    for x in v: 
        assert isinstance(x, numbers.Number)
    fn_v = fn(v)
    def partial(n):
        delta_v = [x for x in v]
        delta_v[n] += delta   
        fn_delta_v = fn(delta_v)
        return (fn_delta_v - fn_v)/delta    
    jac = [partial(n) for n in range(len(v))]
    return jac

# %%
test_step = True
if test_step:
    step = 1e-10
    def brighten_quad(r,c,sz=5,brighten=0.):
        return quad_img[r*sz+c]+brighten
    for brighten in range(1,100):
        bright_img = create_img(brighten_quad,sz=5,brighten=step*brighten)
        bright_img_entropy = entropy_for_img(bright_img, bins_at)
        dentropy = (bright_img_entropy - quad_img_entropy)/(step*brighten)
        print("dentropy = {}\tupdated entropy = {}".format(dentropy, bright_img_entropy))
# Out:
# histogram: img (flattened) =
# [0.32034766100544104,
#  0.20014241620625614,
#  0.1600778494271905,
#  0.2003566128329981,
#  0.31980215318121696,
#  0.1997601697336589,
#  0.08033129233091552,
#  0.039891271701767296,
#  0.07968961149989968,
#  0.19951443351498735,
#  0.1597278722959659,
#  0.04004947393663152,
#  0.00046311513176310975,
#  0.039691447991479334,
#  0.15999221753669227,
#  0.20037643867805177,
#  0.0799168213541616,
#  0.04001261854435854,
#  0.0795852352502677,
#  0.20005218855196952,
#  0.31956246073976297,
#  0.20040600040246836,
#  0.16010830373359528,
#  0.1997657348929769,
#  0.3195899720770684]
# bins_at =
# [-100.0, 0.0, 0.1, 0.2, 0.30000000000000004, 0.4, 100.0]
# >>>> 	histogram: for (-100.0, 0.0): high_fractions =
# []
# >>>> 	histogram: for (0.0, 0.1): high_fractions =
# [0.8033129233091552,
#  0.39891271701767295,
#  0.7968961149989968,
#  0.40049473936631513,
#  0.004631151317631098,
#  0.39691447991479334,
#  0.7991682135416159,
#  0.40012618544358536,
#  0.7958523525026769]
# >>>> 	histogram: for (0.1, 0.2): high_fractions =
# [0.6007784942719049,
#  0.9976016973365889,
#  0.9951443351498734,
#  0.597278722959659,
#  0.5999221753669226,
#  0.6010830373359527,
#  0.9976573489297688]
# >>>> 	histogram: for (0.2, 0.30000000000000004): high_fractions =
# [0.0014241620625612956,
#  0.003566128329980932,
#  0.003764386780517602,
#  0.0005218855196950643,
#  0.004060004024683537]
# >>>> 	histogram: for (0.30000000000000004, 0.4): high_fractions =
# [0.20347661005441003,
#  0.19802153181216925,
#  0.19562460739762927,
#  0.19589972077068368]
# >>>> 	histogram: for (0.4, 100.0): high_fractions =
# []
# image_histo =
# [((-100.0, 0.0), 0.0),
#  ((0.0, 0.1), 4.203691122587557),
#  ((0.1, 0.2), 6.406843066061773),
#  ((0.2, 0.30000000000000004), 10.376129244633233),
#  ((0.30000000000000004, 0.4), 3.220314096682546),
#  ((0.4, 100.0), 0.7930224700348922)]
# bin sum = 25.000000000000004
# img_entropy = 1.387138933119339
# dentropy = 1.7152235187722908	updated entropy = 1.387138933119339
# histogram: img (flattened) =
# [0.32034766110544105,
#  0.20014241630625612,
#  0.16007784952719048,
#  0.20035661293299808,
#  0.31980215328121697,
#  0.19976016983365888,
#  0.08033129243091552,
#  0.0398912718017673,
#  0.07968961159989969,
#  0.19951443361498733,
#  0.1597278723959659,
#  0.04004947403663152,
#  0.0004631152317631098,
#  0.039691448091479335,
#  0.15999221763669225,
#  0.20037643877805175,
#  0.07991682145416161,
#  0.04001261864435854,
#  0.07958523535026771,
#  0.2000521886519695,
#  0.319562460839763,
#  0.20040600050246835,
#  0.16010830383359526,
#  0.19976573499297687,
#  0.3195899721770684]
# bins_at =
# [-100.0, 0.0, 0.1, 0.2, 0.30000000000000004, 0.4, 100.0]
# >>>> 	histogram: for (-100.0, 0.0): high_fractions =
# []
# >>>> 	histogram: for (0.0, 0.1): high_fractions =
# [0.8033129243091552,
#  0.398912718017673,
#  0.7968961159989969,
#  0.40049474036631516,
#  0.004631152317631098,
#  0.3969144809147933,
#  0.799168214541616,
#  0.4001261864435854,
#  0.795852353502677]
# >>>> 	histogram: for (0.1, 0.2): high_fractions =
# [0.6007784952719047,
#  0.9976016983365887,
#  0.9951443361498732,
#  0.5972787239596589,
#  0.5999221763669224,
#  0.6010830383359524,
#  0.9976573499297686]
# >>>> 	histogram: for (0.2, 0.30000000000000004): high_fractions =
# [0.0014241630625611008,
#  0.003566129329980737,
#  0.0037643877805174073,
#  0.0005218865196948694,
#  0.004060005024683342]
# >>>> 	histogram: for (0.30000000000000004, 0.4): high_fractions =
# [0.20347661105441012,
#  0.19802153281216933,
#  0.19562460839762935,
#  0.19589972177068377]
# >>>> 	histogram: for (0.4, 100.0): high_fractions =
# []
# image_histo =
# [((-100.0, 0.0), 0.0),
#  ((0.0, 0.1), 4.203691113587556),
#  ((0.1, 0.2), 6.406843068061775),
#  ((0.2, 0.30000000000000004), 10.376129246633232),
#  ((0.30000000000000004, 0.4), 3.220314097682545),
#  ((0.4, 100.0), 0.7930224740348926)]
# bin sum = 25.0
# img_entropy = 1.387138933290861
# dentropy = 1.7152224085492662	updated entropy = 1.387138933290861
# histogram: img (flattened) =
# [0.32034766120544106,
#  0.20014241640625613,
#  0.1600778496271905,
#  0.2003566130329981,
#  0.319802153381217,
#  0.1997601699336589,
#  0.08033129253091552,
#  0.03989127190176729,
#  0.07968961169989969,
#  0.19951443371498734,
#  0.1597278724959659,
#  0.04004947413663151,
#  0.00046311533176310977,
#  0.03969144819147933,
#  0.15999221773669225,
#  0.20037643887805176,
#  0.0799168215541616,
#  0.04001261874435853,
#  0.0795852354502677,
#  0.2000521887519695,
#  0.319562460939763,
#  0.20040600060246835,
#  0.16010830393359526,
#  0.19976573509297688,
#  0.3195899722770684]
# bins_at =
# [-100.0, 0.0, 0.1, 0.2, 0.30000000000000004, 0.4, 100.0]
# >>>> 	histogram: for (-100.0, 0.0): high_fractions =
# []
# >>>> 	histogram: for (0.0, 0.1): high_fractions =
# [0.8033129253091551,
#  0.3989127190176729,
#  0.7968961169989969,
#  0.40049474136631513,
#  0.0046311533176310975,
#  0.3969144819147933,
#  0.799168215541616,
#  0.4001261874435853,
#  0.795852354502677]
# >>>> 	histogram: for (0.1, 0.2): high_fractions =
# [0.6007784962719048,
#  0.9976016993365888,
#  0.9951443371498733,
#  0.597278724959659,
#  0.5999221773669224,
#  0.6010830393359525,
#  0.9976573509297687]
# >>>> 	histogram: for (0.2, 0.30000000000000004): high_fractions =
# [0.0014241640625611836,
#  0.00356613032998082,
#  0.00376438878051749,
#  0.0005218875196949522,
#  0.004060006024683425]
# >>>> 	histogram: for (0.30000000000000004, 0.4): high_fractions =
# [0.2034766120544102,
#  0.19802153381216941,
#  0.19562460939762943,
#  0.19589972277068385]
# >>>> 	histogram: for (0.4, 100.0): high_fractions =
# []
# image_histo =
# [((-100.0, 0.0), 0.0),
#  ((0.0, 0.1), 4.203691104587557),
#  ((0.1, 0.2), 6.406843070061774),
#  ((0.2, 0.30000000000000004), 10.376129248633232),
#  ((0.30000000000000004, 0.4), 3.220314098682545),
#  ((0.4, 100.0), 0.7930224780348929)]
# bin sum = 25.0
# img_entropy = 1.3871389334623834
# dentropy = 1.7152227786236078	updated entropy = 1.3871389334623834
# histogram: img (flattened) =
# [0.320347661305441,
#  0.20014241650625614,
#  0.1600778497271905,
#  0.2003566131329981,
#  0.31980215348121693,
#  0.1997601700336589,
#  0.08033129263091553,
#  0.03989127200176729,
#  0.0796896117998997,
#  0.19951443381498735,
#  0.1597278725959659,
#  0.040049474236631515,
#  0.00046311543176310975,
#  0.03969144829147933,
#  0.15999221783669226,
#  0.20037643897805177,
#  0.07991682165416161,
#  0.040012618844358534,
#  0.07958523555026771,
#  0.20005218885196951,
#  0.31956246103976294,
#  0.20040600070246836,
#  0.16010830403359527,
#  0.19976573519297688,
#  0.3195899723770684]
# bins_at =
# [-100.0, 0.0, 0.1, 0.2, 0.30000000000000004, 0.4, 100.0]
# >>>> 	histogram: for (-100.0, 0.0): high_fractions =
# []
# >>>> 	histogram: for (0.0, 0.1): high_fractions =
# [0.8033129263091552,
#  0.3989127200176729,
#  0.796896117998997,
#  0.4004947423663151,
#  0.004631154317631097,
#  0.3969144829147933,
#  0.7991682165416161,
#  0.40012618844358533,
#  0.7958523555026771]
# >>>> 	histogram: for (0.1, 0.2): high_fractions =
# [0.6007784972719049,
#  0.9976017003365889,
#  0.9951443381498734,
#  0.597278725959659,
#  0.5999221783669225,
#  0.6010830403359526,
#  0.9976573519297688]
# >>>> 	histogram: for (0.2, 0.30000000000000004): high_fractions =
# [0.0014241650625612663,
#  0.0035661313299809026,
#  0.003764389780517573,
#  0.0005218885196950349,
#  0.004060007024683508]
# >>>> 	histogram: for (0.30000000000000004, 0.4): high_fractions =
# [0.20347661305440973,
#  0.19802153481216894,
#  0.19562461039762896,
#  0.19589972377068338]
# >>>> 	histogram: for (0.4, 100.0): high_fractions =
# []
# image_histo =
# [((-100.0, 0.0), 0.0),
#  ((0.0, 0.1), 4.203691095587557),
#  ((0.1, 0.2), 6.406843072061772),
#  ((0.2, 0.30000000000000004), 10.376129250633232),
#  ((0.30000000000000004, 0.4), 3.2203140996825477),
#  ((0.4, 100.0), 0.793022482034891)]
# bin sum = 25.0
# img_entropy = 1.3871389336339053
# dentropy = 1.715221853437754	updated entropy = 1.3871389336339053
# histogram: img (flattened) =
# [0.320347661405441,
#  0.20014241660625615,
#  0.1600778498271905,
#  0.2003566132329981,
#  0.31980215358121694,
#  0.1997601701336589,
#  0.08033129273091552,
#  0.039891272101767294,
#  0.07968961189989969,
#  0.19951443391498735,
#  0.15972787269596592,
#  0.040049474336631516,
#  0.0004631155317631098,
#  0.03969144839147933,
#  0.15999221793669227,
#  0.20037643907805178,
#  0.07991682175416161,
#  0.040012618944358536,
#  0.0795852356502677,
#  0.20005218895196952,
#  0.31956246113976294,
#  0.20040600080246837,
#  0.16010830413359528,
#  0.1997657352929769,
#  0.3195899724770684]
# bins_at =
# [-100.0, 0.0, 0.1, 0.2, 0.30000000000000004, 0.4, 100.0]
# >>>> 	histogram: for (-100.0, 0.0): high_fractions =
# []
# >>>> 	histogram: for (0.0, 0.1): high_fractions =
# [0.8033129273091552,
#  0.39891272101767294,
#  0.7968961189989968,
#  0.40049474336631513,
#  0.004631155317631097,
#  0.3969144839147933,
#  0.799168217541616,
#  0.40012618944358536,
#  0.795852356502677]
# >>>> 	histogram: for (0.1, 0.2): high_fractions =
# [0.600778498271905,
#  0.997601701336589,
#  0.9951443391498734,
#  0.5972787269596591,
#  0.5999221793669226,
#  0.6010830413359527,
#  0.9976573529297689]
# >>>> 	histogram: for (0.2, 0.30000000000000004): high_fractions =
# [0.001424166062561349,
#  0.0035661323299809853,
#  0.0037643907805176556,
#  0.0005218895196951177,
#  0.004060008024683591]
# >>>> 	histogram: for (0.30000000000000004, 0.4): high_fractions =
# [0.2034766140544098,
#  0.19802153581216903,
#  0.19562461139762904,
#  0.19589972477068346]
# >>>> 	histogram: for (0.4, 100.0): high_fractions =
# []
# image_histo =
# [((-100.0, 0.0), 0.0),
#  ((0.0, 0.1), 4.203691086587557),
#  ((0.1, 0.2), 6.406843074061772),
#  ((0.2, 0.30000000000000004), 10.376129252633232),
#  ((0.30000000000000004, 0.4), 3.2203141006825478),
#  ((0.4, 100.0), 0.7930224860348913)]
# bin sum = 25.000000000000004
# img_entropy = 1.3871389338054274
# dentropy = 1.7152217424154514	updated entropy = 1.3871389338054274
# histogram: img (flattened) =
# [0.32034766150544103,
#  0.20014241670625613,
#  0.16007784992719049,
#  0.2003566133329981,
#  0.31980215368121695,
#  0.19976017023365888,
#  0.08033129283091552,
#  0.039891272201767296,
#  0.07968961199989968,
#  0.19951443401498734,
#  0.1597278727959659,
#  0.04004947443663152,
#  0.00046311563176310976,
#  0.039691448491479334,
#  0.15999221803669225,
#  0.20037643917805176,
#  0.0799168218541616,
#  0.04001261904435854,
#  0.0795852357502677,
#  0.2000521890519695,
#  0.31956246123976295,
#  0.20040600090246835,
#  0.16010830423359526,
#  0.19976573539297687,
#  0.3195899725770684]
# bins_at =
# [-100.0, 0.0, 0.1, 0.2, 0.30000000000000004, 0.4, 100.0]
# >>>> 	histogram: for (-100.0, 0.0): high_fractions =
# []
# >>>> 	histogram: for (0.0, 0.1): high_fractions =
# [0.8033129283091551,
#  0.3989127220176729,
#  0.7968961199989968,
#  0.40049474436631516,
#  0.004631156317631098,
#  0.3969144849147933,
#  0.799168218541616,
#  0.40012619044358533,
#  0.7958523575026769]
# >>>> 	histogram: for (0.1, 0.2): high_fractions =
# [0.6007784992719047,
#  0.9976017023365887,
#  0.9951443401498733,
#  0.5972787279596589,
#  0.5999221803669225,
#  0.6010830423359526,
#  0.9976573539297686]
# >>>> 	histogram: for (0.2, 0.30000000000000004): high_fractions =
# [0.0014241670625611542,
#  0.0035661333299807905,
#  0.0037643917805174607,
#  0.0005218905196949228,
#  0.004060009024683396]
# >>>> 	histogram: for (0.30000000000000004, 0.4): high_fractions =
# [0.2034766150544099,
#  0.1980215368121691,
#  0.19562461239762913,
#  0.19589972577068354]
# >>>> 	histogram: for (0.4, 100.0): high_fractions =
# []
# image_histo =
# [((-100.0, 0.0), 0.0),
#  ((0.0, 0.1), 4.203691077587557),
#  ((0.1, 0.2), 6.406843076061774),
#  ((0.2, 0.30000000000000004), 10.376129254633232),
#  ((0.30000000000000004, 0.4), 3.220314101682546),
#  ((0.4, 100.0), 0.7930224900348917)]
# bin sum = 25.000000000000004
# img_entropy = 1.3871389339769495
# dentropy = 1.7152216684005832	updated entropy = 1.3871389339769495
# histogram: img (flattened) =
# [0.32034766160544104,
#  0.20014241680625613,
#  0.1600778500271905,
#  0.2003566134329981,
#  0.31980215378121696,
#  0.1997601703336589,
#  0.08033129293091552,
#  0.0398912723017673,
#  0.07968961209989969,
#  0.19951443411498734,
#  0.1597278728959659,
#  0.04004947453663152,
#  0.0004631157317631098,
#  0.039691448591479335,
#  0.15999221813669226,
#  0.20037643927805177,
#  0.07991682195416161,
#  0.04001261914435854,
#  0.07958523585026771,
#  0.2000521891519695,
#  0.31956246133976296,
#  0.20040600100246836,
#  0.16010830433359527,
#  0.19976573549297688,
#  0.3195899726770684]
# bins_at =
# [-100.0, 0.0, 0.1, 0.2, 0.30000000000000004, 0.4, 100.0]
# >>>> 	histogram: for (-100.0, 0.0): high_fractions =
# []
# >>>> 	histogram: for (0.0, 0.1): high_fractions =
# [0.8033129293091552,
#  0.39891272301767294,
#  0.7968961209989969,
#  0.4004947453663152,
#  0.004631157317631098,
#  0.39691448591479334,
#  0.7991682195416161,
#  0.40012619144358536,
#  0.795852358502677]
# >>>> 	histogram: for (0.1, 0.2): high_fractions =
# [0.6007785002719048,
#  0.9976017033365888,
#  0.9951443411498734,
#  0.5972787289596589,
#  0.5999221813669225,
#  0.6010830433359526,
#  0.9976573549297687]
# >>>> 	histogram: for (0.2, 0.30000000000000004): high_fractions =
# [0.001424168062561237,
#  0.0035661343299808732,
#  0.0037643927805175435,
#  0.0005218915196950056,
#  0.0040600100246834785]
# >>>> 	histogram: for (0.30000000000000004, 0.4): high_fractions =
# [0.20347661605440998,
#  0.1980215378121692,
#  0.1956246133976292,
#  0.19589972677068362]
# >>>> 	histogram: for (0.4, 100.0): high_fractions =
# []
# image_histo =
# [((-100.0, 0.0), 0.0),
#  ((0.0, 0.1), 4.203691068587556),
#  ((0.1, 0.2), 6.406843078061774),
#  ((0.2, 0.30000000000000004), 10.376129256633233),
#  ((0.30000000000000004, 0.4), 3.220314102682546),
#  ((0.4, 100.0), 0.793022494034892)]
# bin sum = 25.000000000000004
# img_entropy = 1.3871389341484717
# dentropy = 1.71522161553282	updated entropy = 1.3871389341484717
# histogram: img (flattened) =
# [0.32034766170544104,
#  0.20014241690625614,
#  0.1600778501271905,
#  0.2003566135329981,
#  0.31980215388121697,
#  0.1997601704336589,
#  0.08033129303091552,
#  0.03989127240176729,
#  0.07968961219989969,
#  0.19951443421498735,
#  0.1597278729959659,
#  0.04004947463663151,
#  0.0004631158317631098,
#  0.03969144869147933,
#  0.15999221823669227,
#  0.20037643937805177,
#  0.0799168220541616,
#  0.04001261924435853,
#  0.0795852359502677,
#  0.20005218925196952,
#  0.31956246143976297,
#  0.20040600110246837,
#  0.16010830443359528,
#  0.1997657355929769,
#  0.3195899727770684]
# bins_at =
# [-100.0, 0.0, 0.1, 0.2, 0.30000000000000004, 0.4, 100.0]
# >>>> 	histogram: for (-100.0, 0.0): high_fractions =
# []
# >>>> 	histogram: for (0.0, 0.1): high_fractions =
# [0.8033129303091552,
#  0.3989127240176729,
#  0.7968961219989968,
#  0.4004947463663151,
#  0.0046311583176310974,
#  0.39691448691479325,
#  0.799168220541616,
#  0.4001261924435853,
#  0.795852359502677]
# >>>> 	histogram: for (0.1, 0.2): high_fractions =
# [0.6007785012719049,
#  0.9976017043365889,
#  0.9951443421498735,
#  0.597278729959659,
#  0.5999221823669226,
#  0.6010830443359527,
#  0.9976573559297688]
# >>>> 	histogram: for (0.2, 0.30000000000000004): high_fractions =
# [0.0014241690625613197,
#  0.003566135329980956,
#  0.0037643937805176262,
#  0.0005218925196950883,
#  0.004060011024683561]
# >>>> 	histogram: for (0.30000000000000004, 0.4): high_fractions =
# [0.20347661705441006,
#  0.19802153881216927,
#  0.1956246143976293,
#  0.1958997277706837]
# >>>> 	histogram: for (0.4, 100.0): high_fractions =
# []
# image_histo =
# [((-100.0, 0.0), 0.0),
#  ((0.0, 0.1), 4.203691059587557),
#  ((0.1, 0.2), 6.406843080061773),
#  ((0.2, 0.30000000000000004), 10.376129258633233),
#  ((0.30000000000000004, 0.4), 3.2203141036825462),
#  ((0.4, 100.0), 0.7930224980348923)]
# bin sum = 25.000000000000004
# img_entropy = 1.3871389343199938
# dentropy = 1.7152215758819978	updated entropy = 1.3871389343199938
# histogram: img (flattened) =
# [0.32034766180544105,
#  0.20014241700625612,
#  0.16007785022719048,
#  0.2003566136329981,
#  0.319802153981217,
#  0.19976017053365888,
#  0.08033129313091553,
#  0.03989127250176729,
#  0.0796896122998997,
#  0.19951443431498733,
#  0.1597278730959659,
#  0.040049474736631514,
#  0.00046311593176310976,
#  0.03969144879147933,
#  0.15999221833669225,
#  0.20037643947805175,
#  0.07991682215416161,
#  0.040012619344358534,
#  0.07958523605026771,
#  0.2000521893519695,
#  0.319562461539763,
#  0.20040600120246835,
#  0.16010830453359526,
#  0.19976573569297687,
#  0.3195899728770684]
# bins_at =
# [-100.0, 0.0, 0.1, 0.2, 0.30000000000000004, 0.4, 100.0]
# >>>> 	histogram: for (-100.0, 0.0): high_fractions =
# []
# >>>> 	histogram: for (0.0, 0.1): high_fractions =
# [0.8033129313091553,
#  0.3989127250176729,
#  0.7968961229989969,
#  0.40049474736631513,
#  0.004631159317631097,
#  0.3969144879147933,
#  0.799168221541616,
#  0.4001261934435853,
#  0.795852360502677]
# >>>> 	histogram: for (0.1, 0.2): high_fractions =
# [0.6007785022719048,
#  0.9976017053365888,
#  0.9951443431498732,
#  0.5972787309596589,
#  0.5999221833669224,
#  0.6010830453359525,
#  0.9976573569297686]
# >>>> 	histogram: for (0.2, 0.30000000000000004): high_fractions =
# [0.001424170062561125,
#  0.003566136329980761,
#  0.0037643947805174314,
#  0.0005218935196948935,
#  0.0040600120246833665]
# >>>> 	histogram: for (0.30000000000000004, 0.4): high_fractions =
# [0.20347661805441014,
#  0.19802153981216936,
#  0.19562461539762938,
#  0.1958997287706838]
# >>>> 	histogram: for (0.4, 100.0): high_fractions =
# []
# image_histo =
# [((-100.0, 0.0), 0.0),
#  ((0.0, 0.1), 4.203691050587556),
#  ((0.1, 0.2), 6.406843082061773),
#  ((0.2, 0.30000000000000004), 10.376129260633231),
#  ((0.30000000000000004, 0.4), 3.220314104682545),
#  ((0.4, 100.0), 0.7930225020348927)]
# bin sum = 25.0
# img_entropy = 1.387138934491516
# dentropy = 1.7152215450424693	updated entropy = 1.387138934491516
# histogram: img (flattened) =
# [0.32034766190544106,
#  0.20014241710625613,
#  0.1600778503271905,
#  0.2003566137329981,
#  0.319802154081217,
#  0.1997601706336589,
#  0.08033129323091552,
#  0.039891272601767294,
#  0.07968961239989969,
#  0.19951443441498734,
#  0.1597278731959659,
#  0.040049474836631516,
#  0.0004631160317631098,
#  0.03969144889147933,
#  0.15999221843669226,
#  0.20037643957805176,
#  0.0799168222541616,
#  0.040012619444358535,
#  0.0795852361502677,
#  0.2000521894519695,
#  0.319562461639763,
#  0.20040600130246836,
#  0.16010830463359527,
#  0.19976573579297688,
#  0.3195899729770684]
# bins_at =
# [-100.0, 0.0, 0.1, 0.2, 0.30000000000000004, 0.4, 100.0]
# >>>> 	histogram: for (-100.0, 0.0): high_fractions =
# []
# >>>> 	histogram: for (0.0, 0.1): high_fractions =
# [0.8033129323091551,
#  0.3989127260176729,
#  0.7968961239989969,
#  0.40049474836631516,
#  0.004631160317631097,
#  0.3969144889147933,
#  0.799168222541616,
#  0.4001261944435853,
#  0.795852361502677]
# >>>> 	histogram: for (0.1, 0.2): high_fractions =
# [0.6007785032719049,
#  0.9976017063365888,
#  0.9951443441498733,
#  0.597278731959659,
#  0.5999221843669225,
#  0.6010830463359526,
#  0.9976573579297687]
# >>>> 	histogram: for (0.2, 0.30000000000000004): high_fractions =
# [0.0014241710625612076,
#  0.003566137329980844,
#  0.003764395780517514,
#  0.0005218945196949762,
#  0.004060013024683449]
# >>>> 	histogram: for (0.30000000000000004, 0.4): high_fractions =
# [0.20347661905441022,
#  0.19802154081216944,
#  0.19562461639762946,
#  0.19589972977068387]
# >>>> 	histogram: for (0.4, 100.0): high_fractions =
# []
# image_histo =
# [((-100.0, 0.0), 0.0),
#  ((0.0, 0.1), 4.2036910415875575),
#  ((0.1, 0.2), 6.406843084061773),
#  ((0.2, 0.30000000000000004), 10.376129262633231),
#  ((0.30000000000000004, 0.4), 3.220314105682545),
#  ((0.4, 100.0), 0.793022506034893)]
# bin sum = 25.0
# img_entropy = 1.3871389346630383
# dentropy = 1.7152217424154514	updated entropy = 1.3871389346630383
# histogram: img (flattened) =
# [0.320347662005441,
#  0.20014241720625614,
#  0.1600778504271905,
#  0.2003566138329981,
#  0.31980215418121694,
#  0.1997601707336589,
#  0.08033129333091552,
#  0.039891272701767296,
#  0.07968961249989968,
#  0.19951443451498735,
#  0.1597278732959659,
#  0.04004947493663152,
#  0.00046311613176310977,
#  0.03969144899147933,
#  0.15999221853669227,
#  0.20037643967805177,
#  0.0799168223541616,
#  0.04001261954435854,
#  0.0795852362502677,
#  0.20005218955196952,
#  0.31956246173976294,
#  0.20040600140246836,
#  0.16010830473359527,
#  0.1997657358929769,
#  0.3195899730770684]
# bins_at =
# [-100.0, 0.0, 0.1, 0.2, 0.30000000000000004, 0.4, 100.0]
# >>>> 	histogram: for (-100.0, 0.0): high_fractions =
# []
# >>>> 	histogram: for (0.0, 0.1): high_fractions =
# [0.8033129333091551,
#  0.39891272701767294,
#  0.7968961249989968,
#  0.40049474936631513,
#  0.004631161317631098,
#  0.39691448991479333,
#  0.799168223541616,
#  0.40012619544358535,
#  0.795852362502677]
# >>>> 	histogram: for (0.1, 0.2): high_fractions =
# [0.6007785042719049,
#  0.9976017073365889,
#  0.9951443451498734,
#  0.597278732959659,
#  0.5999221853669225,
#  0.6010830473359526,
#  0.9976573589297688]
# >>>> 	histogram: for (0.2, 0.30000000000000004): high_fractions =
# [0.0014241720625612904,
#  0.0035661383299809266,
#  0.003764396780517597,
#  0.000521895519695059,
#  0.004060014024683532]
# >>>> 	histogram: for (0.30000000000000004, 0.4): high_fractions =
# [0.20347662005440975,
#  0.19802154181216897,
#  0.19562461739762899,
#  0.1958997307706834]
# >>>> 	histogram: for (0.4, 100.0): high_fractions =
# []
# image_histo =
# [((-100.0, 0.0), 0.0),
#  ((0.0, 0.1), 4.203691032587558),
#  ((0.1, 0.2), 6.406843086061772),
#  ((0.2, 0.30000000000000004), 10.376129264633231),
#  ((0.30000000000000004, 0.4), 3.2203141066825474),
#  ((0.4, 100.0), 0.7930225100348911)]
# bin sum = 25.0
# img_entropy = 1.3871389348345602
# dentropy = 1.715221500184973	updated entropy = 1.3871389348345602
# histogram: img (flattened) =
# [0.320347662105441,
#  0.20014241730625612,
#  0.16007785052719048,
#  0.20035661393299808,
#  0.31980215428121694,
#  0.19976017083365888,
#  0.08033129343091552,
#  0.0398912728017673,
#  0.07968961259989969,
#  0.19951443461498733,
#  0.1597278733959659,
#  0.04004947503663152,
#  0.00046311623176310975,
#  0.039691449091479335,
#  0.15999221863669225,
#  0.20037643977805175,
#  0.07991682245416161,
#  0.04001261964435854,
#  0.07958523635026771,
#  0.2000521896519695,
#  0.31956246183976295,
#  0.20040600150246834,
#  0.16010830483359526,
#  0.19976573599297687,
#  0.3195899731770684]
# bins_at =
# [-100.0, 0.0, 0.1, 0.2, 0.30000000000000004, 0.4, 100.0]
# >>>> 	histogram: for (-100.0, 0.0): high_fractions =
# []
# >>>> 	histogram: for (0.0, 0.1): high_fractions =
# [0.8033129343091552,
#  0.39891272801767297,
#  0.7968961259989968,
#  0.40049475036631516,
#  0.004631162317631097,
#  0.3969144909147933,
#  0.7991682245416161,
#  0.4001261964435854,
#  0.7958523635026771]
# >>>> 	histogram: for (0.1, 0.2): high_fractions =
# [0.6007785052719047,
#  0.9976017083365887,
#  0.9951443461498732,
#  0.5972787339596588,
#  0.5999221863669224,
#  0.6010830483359525,
#  0.9976573599297686]
# >>>> 	histogram: for (0.2, 0.30000000000000004): high_fractions =
# [0.0014241730625610956,
#  0.003566139329980732,
#  0.003764397780517402,
#  0.0005218965196948642,
#  0.004060015024683337]
# >>>> 	histogram: for (0.30000000000000004, 0.4): high_fractions =
# [0.20347662105440983,
#  0.19802154281216905,
#  0.19562461839762907,
#  0.19589973177068348]
# >>>> 	histogram: for (0.4, 100.0): high_fractions =
# []
# image_histo =
# [((-100.0, 0.0), 0.0),
#  ((0.0, 0.1), 4.203691023587557),
#  ((0.1, 0.2), 6.406843088061774),
#  ((0.2, 0.30000000000000004), 10.376129266633232),
#  ((0.30000000000000004, 0.4), 3.220314107682546),
#  ((0.4, 100.0), 0.7930225140348914)]
# bin sum = 25.000000000000004
# img_entropy = 1.3871389350060825
# dentropy = 1.7152216684005832	updated entropy = 1.3871389350060825
# histogram: img (flattened) =
# [0.32034766220544103,
#  0.20014241740625613,
#  0.1600778506271905,
#  0.2003566140329981,
#  0.31980215438121695,
#  0.1997601709336589,
#  0.08033129353091552,
#  0.03989127290176729,
#  0.07968961269989969,
#  0.19951443471498734,
#  0.1597278734959659,
#  0.04004947513663151,
#  0.0004631163317631098,
#  0.03969144919147933,
#  0.15999221873669225,
#  0.20037643987805176,
#  0.0799168225541616,
#  0.04001261974435853,
#  0.0795852364502677,
#  0.2000521897519695,
#  0.31956246193976295,
#  0.20040600160246835,
#  0.16010830493359526,
#  0.19976573609297688,
#  0.3195899732770684]
# bins_at =
# [-100.0, 0.0, 0.1, 0.2, 0.30000000000000004, 0.4, 100.0]
# >>>> 	histogram: for (-100.0, 0.0): high_fractions =
# []
# >>>> 	histogram: for (0.0, 0.1): high_fractions =
# [0.8033129353091552,
#  0.3989127290176729,
#  0.7968961269989968,
#  0.4004947513663151,
#  0.004631163317631097,
#  0.3969144919147933,
#  0.799168225541616,
#  0.4001261974435853,
#  0.7958523645026769]
# >>>> 	histogram: for (0.1, 0.2): high_fractions =
# [0.6007785062719048,
#  0.9976017093365888,
#  0.9951443471498733,
#  0.5972787349596589,
#  0.5999221873669225,
#  0.6010830493359526,
#  0.9976573609297686]
# >>>> 	histogram: for (0.2, 0.30000000000000004): high_fractions =
# [0.0014241740625611783,
#  0.0035661403299808146,
#  0.003764398780517485,
#  0.0005218975196949469,
#  0.00406001602468342]
# >>>> 	histogram: for (0.30000000000000004, 0.4): high_fractions =
# [0.20347662205440992,
#  0.19802154381216913,
#  0.19562461939762915,
#  0.19589973277068357]
# >>>> 	histogram: for (0.4, 100.0): high_fractions =
# []
# image_histo =
# [((-100.0, 0.0), 0.0),
#  ((0.0, 0.1), 4.203691014587557),
#  ((0.1, 0.2), 6.406843090061773),
#  ((0.2, 0.30000000000000004), 10.376129268633232),
#  ((0.30000000000000004, 0.4), 3.220314108682546),
#  ((0.4, 100.0), 0.7930225180348918)]
# bin sum = 25.0
# img_entropy = 1.3871389351776044
# dentropy = 1.7152214691297838	updated entropy = 1.3871389351776044
# histogram: img (flattened) =
# [0.32034766230544104,
#  0.20014241750625614,
#  0.1600778507271905,
#  0.2003566141329981,
#  0.31980215448121696,
#  0.1997601710336589,
#  0.08033129363091553,
#  0.03989127300176729,
#  0.0796896127998997,
#  0.19951443481498735,
#  0.1597278735959659,
#  0.040049475236631514,
#  0.00046311643176310976,
#  0.03969144929147933,
#  0.15999221883669226,
#  0.20037643997805177,
#  0.07991682265416161,
#  0.040012619844358534,
#  0.07958523655026771,
#  0.20005218985196951,
#  0.31956246203976296,
#  0.20040600170246836,
#  0.16010830503359527,
#  0.19976573619297688,
#  0.3195899733770684]
# bins_at =
# [-100.0, 0.0, 0.1, 0.2, 0.30000000000000004, 0.4, 100.0]
# >>>> 	histogram: for (-100.0, 0.0): high_fractions =
# []
# >>>> 	histogram: for (0.0, 0.1): high_fractions =
# [0.8033129363091552,
#  0.3989127300176729,
#  0.7968961279989969,
#  0.4004947523663151,
#  0.004631164317631098,
#  0.3969144929147933,
#  0.7991682265416161,
#  0.4001261984435853,
#  0.795852365502677]
# >>>> 	histogram: for (0.1, 0.2): high_fractions =
# [0.6007785072719048,
#  0.9976017103365888,
#  0.9951443481498734,
#  0.597278735959659,
#  0.5999221883669226,
#  0.6010830503359527,
#  0.9976573619297687]
# >>>> 	histogram: for (0.2, 0.30000000000000004): high_fractions =
# [0.001424175062561261,
#  0.0035661413299808973,
#  0.0037643997805175675,
#  0.0005218985196950297,
#  0.004060017024683503]
# >>>> 	histogram: for (0.30000000000000004, 0.4): high_fractions =
# [0.20347662305441,
#  0.19802154481216921,
#  0.19562462039762923,
#  0.19589973377068365]
# >>>> 	histogram: for (0.4, 100.0): high_fractions =
# []
# image_histo =
# [((-100.0, 0.0), 0.0),
#  ((0.0, 0.1), 4.203691005587557),
#  ((0.1, 0.2), 6.406843092061773),
#  ((0.2, 0.30000000000000004), 10.376129270633232),
#  ((0.30000000000000004, 0.4), 3.2203141096825463),
#  ((0.4, 100.0), 0.7930225220348921)]
# bin sum = 25.000000000000004
# img_entropy = 1.3871389353491266
# dentropy = 1.7152214569295308	updated entropy = 1.3871389353491266
# histogram: img (flattened) =
# [0.32034766240544105,
#  0.20014241760625615,
#  0.1600778508271905,
#  0.2003566142329981,
#  0.31980215458121697,
#  0.1997601711336589,
#  0.08033129373091552,
#  0.039891273101767294,
#  0.07968961289989969,
#  0.19951443491498735,
#  0.15972787369596592,
#  0.040049475336631515,
#  0.0004631165317631098,
#  0.03969144939147933,
#  0.15999221893669227,
#  0.20037644007805178,
#  0.0799168227541616,
#  0.040012619944358535,
#  0.0795852366502677,
#  0.20005218995196952,
#  0.31956246213976297,
#  0.20040600180246837,
#  0.16010830513359528,
#  0.1997657362929769,
#  0.3195899734770684]
# bins_at =
# [-100.0, 0.0, 0.1, 0.2, 0.30000000000000004, 0.4, 100.0]
# >>>> 	histogram: for (-100.0, 0.0): high_fractions =
# []
# >>>> 	histogram: for (0.0, 0.1): high_fractions =
# [0.8033129373091552,
#  0.39891273101767294,
#  0.7968961289989969,
#  0.4004947533663151,
#  0.004631165317631098,
#  0.3969144939147933,
#  0.799168227541616,
#  0.40012619944358535,
#  0.795852366502677]
# >>>> 	histogram: for (0.1, 0.2): high_fractions =
# [0.6007785082719049,
#  0.9976017113365889,
#  0.9951443491498735,
#  0.597278736959659,
#  0.5999221893669227,
#  0.6010830513359527,
#  0.9976573629297688]
# >>>> 	histogram: for (0.2, 0.30000000000000004): high_fractions =
# [0.0014241760625613438,
#  0.00356614232998098,
#  0.0037644007805176503,
#  0.0005218995196951124,
#  0.004060018024683585]
# >>>> 	histogram: for (0.30000000000000004, 0.4): high_fractions =
# [0.20347662405441008,
#  0.1980215458121693,
#  0.19562462139762932,
#  0.19589973477068373]
# >>>> 	histogram: for (0.4, 100.0): high_fractions =
# []
# image_histo =
# [((-100.0, 0.0), 0.0),
#  ((0.0, 0.1), 4.203690996587557),
#  ((0.1, 0.2), 6.406843094061772),
#  ((0.2, 0.30000000000000004), 10.376129272633232),
#  ((0.30000000000000004, 0.4), 3.2203141106825464),
#  ((0.4, 100.0), 0.7930225260348924)]
# bin sum = 25.0
# img_entropy = 1.3871389355206487
# dentropy = 1.7152214463559783	updated entropy = 1.3871389355206487
# histogram: img (flattened) =
# [0.32034766250544106,
#  0.20014241770625613,
#  0.16007785092719048,
#  0.2003566143329981,
#  0.319802154681217,
#  0.19976017123365888,
#  0.08033129383091552,
#  0.039891273201767295,
#  0.07968961299989968,
#  0.19951443501498733,
#  0.1597278737959659,
#  0.04004947543663152,
#  0.0004631166317631098,
#  0.03969144949147933,
#  0.15999221903669225,
#  0.20037644017805176,
#  0.0799168228541616,
#  0.040012620044358536,
#  0.0795852367502677,
#  0.2000521900519695,
#  0.319562462239763,
#  0.20040600190246835,
#  0.16010830523359526,
#  0.19976573639297687,
#  0.3195899735770684]
# bins_at =
# [-100.0, 0.0, 0.1, 0.2, 0.30000000000000004, 0.4, 100.0]
# >>>> 	histogram: for (-100.0, 0.0): high_fractions =
# []
# >>>> 	histogram: for (0.0, 0.1): high_fractions =
# [0.8033129383091551,
#  0.3989127320176729,
#  0.7968961299989968,
#  0.40049475436631515,
#  0.004631166317631098,
#  0.3969144949147933,
#  0.799168228541616,
#  0.4001262004435853,
#  0.795852367502677]
# >>>> 	histogram: for (0.1, 0.2): high_fractions =
# [0.6007785092719048,
#  0.9976017123365888,
#  0.9951443501498732,
#  0.5972787379596589,
#  0.5999221903669224,
#  0.6010830523359525,
#  0.9976573639297687]
# >>>> 	histogram: for (0.2, 0.30000000000000004): high_fractions =
# [0.001424177062561149,
#  0.0035661433299807852,
#  0.0037644017805174555,
#  0.0005219005196949176,
#  0.0040600190246833905]
# >>>> 	histogram: for (0.30000000000000004, 0.4): high_fractions =
# [0.20347662505441017,
#  0.19802154681216938,
#  0.1956246223976294,
#  0.1958997357706838]
# >>>> 	histogram: for (0.4, 100.0): high_fractions =
# []
# image_histo =
# [((-100.0, 0.0), 0.0),
#  ((0.0, 0.1), 4.203690987587557),
#  ((0.1, 0.2), 6.406843096061774),
#  ((0.2, 0.30000000000000004), 10.376129274633232),
#  ((0.30000000000000004, 0.4), 3.220314111682545),
#  ((0.4, 100.0), 0.7930225300348928)]
# bin sum = 25.0
# img_entropy = 1.387138935692171
# dentropy = 1.7152215758819978	updated entropy = 1.387138935692171
# histogram: img (flattened) =
# [0.320347662605441,
#  0.20014241780625613,
#  0.1600778510271905,
#  0.2003566144329981,
#  0.31980215478121693,
#  0.1997601713336589,
#  0.08033129393091552,
#  0.0398912733017673,
#  0.07968961309989969,
#  0.19951443511498734,
#  0.1597278738959659,
#  0.04004947553663152,
#  0.00046311673176310976,
#  0.039691449591479334,
#  0.15999221913669226,
#  0.20037644027805177,
#  0.07991682295416161,
#  0.04001262014435854,
#  0.07958523685026771,
#  0.2000521901519695,
#  0.31956246233976293,
#  0.20040600200246836,
#  0.16010830533359527,
#  0.19976573649297688,
#  0.3195899736770684]
# bins_at =
# [-100.0, 0.0, 0.1, 0.2, 0.30000000000000004, 0.4, 100.0]
# >>>> 	histogram: for (-100.0, 0.0): high_fractions =
# []
# >>>> 	histogram: for (0.0, 0.1): high_fractions =
# [0.8033129393091551,
#  0.39891273301767294,
#  0.7968961309989969,
#  0.4004947553663152,
#  0.004631167317631097,
#  0.39691449591479333,
#  0.799168229541616,
#  0.40012620144358535,
#  0.795852368502677]
# >>>> 	histogram: for (0.1, 0.2): high_fractions =
# [0.6007785102719049,
#  0.9976017133365889,
#  0.9951443511498733,
#  0.597278738959659,
#  0.5999221913669225,
#  0.6010830533359526,
#  0.9976573649297688]
# >>>> 	histogram: for (0.2, 0.30000000000000004): high_fractions =
# [0.0014241780625612317,
#  0.003566144329980868,
#  0.003764402780517538,
#  0.0005219015196950003,
#  0.004060020024683473]
# >>>> 	histogram: for (0.30000000000000004, 0.4): high_fractions =
# [0.2034766260544097,
#  0.1980215478121689,
#  0.19562462339762893,
#  0.19589973677068334]
# >>>> 	histogram: for (0.4, 100.0): high_fractions =
# []
# image_histo =
# [((-100.0, 0.0), 0.0),
#  ((0.0, 0.1), 4.203690978587557),
#  ((0.1, 0.2), 6.406843098061774),
#  ((0.2, 0.30000000000000004), 10.376129276633232),
#  ((0.30000000000000004, 0.4), 3.2203141126825474),
#  ((0.4, 100.0), 0.7930225340348909)]
# bin sum = 25.0
# img_entropy = 1.387138935863693
# dentropy = 1.715221428940715	updated entropy = 1.387138935863693
# histogram: img (flattened) =
# [0.320347662705441,
#  0.20014241790625614,
#  0.1600778511271905,
#  0.2003566145329981,
#  0.31980215488121694,
#  0.1997601714336589,
#  0.08033129403091552,
#  0.0398912734017673,
#  0.07968961319989969,
#  0.19951443521498735,
#  0.1597278739959659,
#  0.04004947563663152,
#  0.0004631168317631098,
#  0.039691449691479336,
#  0.15999221923669227,
#  0.20037644037805177,
#  0.0799168230541616,
#  0.04001262024435854,
#  0.0795852369502677,
#  0.20005219025196952,
#  0.31956246243976294,
#  0.20040600210246837,
#  0.16010830543359528,
#  0.1997657365929769,
#  0.3195899737770684]
# bins_at =
# [-100.0, 0.0, 0.1, 0.2, 0.30000000000000004, 0.4, 100.0]
# >>>> 	histogram: for (-100.0, 0.0): high_fractions =
# []
# >>>> 	histogram: for (0.0, 0.1): high_fractions =
# [0.8033129403091551,
#  0.39891273401767297,
#  0.7968961319989968,
#  0.40049475636631515,
#  0.004631168317631097,
#  0.39691449691479336,
#  0.799168230541616,
#  0.4001262024435854,
#  0.795852369502677]
# >>>> 	histogram: for (0.1, 0.2): high_fractions =
# [0.600778511271905,
#  0.997601714336589,
#  0.9951443521498734,
#  0.5972787399596591,
#  0.5999221923669226,
#  0.6010830543359527,
#  0.9976573659297688]
# >>>> 	histogram: for (0.2, 0.30000000000000004): high_fractions =
# [0.0014241790625613144,
#  0.0035661453299809507,
#  0.003764403780517621,
#  0.0005219025196950831,
#  0.004060021024683556]
# >>>> 	histogram: for (0.30000000000000004, 0.4): high_fractions =
# [0.20347662705440978, 0.198021548812169, 0.195624624397629, 0.19589973777068342]
# >>>> 	histogram: for (0.4, 100.0): high_fractions =
# []
# image_histo =
# [((-100.0, 0.0), 0.0),
#  ((0.0, 0.1), 4.203690969587557),
#  ((0.1, 0.2), 6.4068431000617725),
#  ((0.2, 0.30000000000000004), 10.376129278633233),
#  ((0.30000000000000004, 0.4), 3.2203141136825475),
#  ((0.4, 100.0), 0.7930225380348912)]
# bin sum = 25.0
# img_entropy = 1.387138936035215
# dentropy = 1.7152214216843555	updated entropy = 1.387138936035215
# histogram: img (flattened) =
# [0.320347662805441,
#  0.20014241800625612,
#  0.16007785122719048,
#  0.2003566146329981,
#  0.31980215498121695,
#  0.19976017153365888,
#  0.08033129413091553,
#  0.03989127350176729,
#  0.0796896132998997,
#  0.19951443531498733,
#  0.1597278740959659,
#  0.040049475736631514,
#  0.00046311693176310977,
#  0.03969144979147933,
#  0.15999221933669225,
#  0.20037644047805175,
#  0.07991682315416161,
#  0.040012620344358533,
#  0.07958523705026771,
#  0.2000521903519695,
#  0.31956246253976295,
#  0.20040600220246835,
#  0.16010830553359526,
#  0.19976573669297687,
#  0.3195899738770684]
# bins_at =
# [-100.0, 0.0, 0.1, 0.2, 0.30000000000000004, 0.4, 100.0]
# >>>> 	histogram: for (-100.0, 0.0): high_fractions =
# []
# >>>> 	histogram: for (0.0, 0.1): high_fractions =
# [0.8033129413091552,
#  0.3989127350176729,
#  0.7968961329989969,
#  0.4004947573663151,
#  0.004631169317631098,
#  0.3969144979147933,
#  0.7991682315416161,
#  0.4001262034435853,
#  0.7958523705026771]
# >>>> 	histogram: for (0.1, 0.2): high_fractions =
# [0.6007785122719047,
#  0.9976017153365887,
#  0.9951443531498733,
#  0.5972787409596588,
#  0.5999221933669224,
#  0.6010830553359525,
#  0.9976573669297686]
# >>>> 	histogram: for (0.2, 0.30000000000000004): high_fractions =
# [0.0014241800625611196,
#  0.003566146329980756,
#  0.003764404780517426,
#  0.0005219035196948882,
#  0.004060022024683361]
# >>>> 	histogram: for (0.30000000000000004, 0.4): high_fractions =
# [0.20347662805440986,
#  0.19802154981216907,
#  0.1956246253976291,
#  0.1958997387706835]
# >>>> 	histogram: for (0.4, 100.0): high_fractions =
# []
# image_histo =
# [((-100.0, 0.0), 0.0),
#  ((0.0, 0.1), 4.203690960587557),
#  ((0.1, 0.2), 6.406843102061774),
#  ((0.2, 0.30000000000000004), 10.376129280633231),
#  ((0.30000000000000004, 0.4), 3.2203141146825462),
#  ((0.4, 100.0), 0.7930225420348915)]
# bin sum = 25.0
# img_entropy = 1.3871389362067372
# dentropy = 1.715221415191823	updated entropy = 1.3871389362067372
# histogram: img (flattened) =
# [0.32034766290544103,
#  0.20014241810625613,
#  0.1600778513271905,
#  0.2003566147329981,
#  0.31980215508121695,
#  0.1997601716336589,
#  0.08033129423091552,
#  0.039891273601767294,
#  0.07968961339989969,
#  0.19951443541498734,
#  0.1597278741959659,
#  0.040049475836631515,
#  0.00046311703176310975,
#  0.03969144989147933,
#  0.15999221943669226,
#  0.20037644057805176,
#  0.0799168232541616,
#  0.040012620444358535,
#  0.0795852371502677,
#  0.2000521904519695,
#  0.31956246263976296,
#  0.20040600230246836,
#  0.16010830563359527,
#  0.19976573679297688,
#  0.3195899739770684]
# bins_at =
# [-100.0, 0.0, 0.1, 0.2, 0.30000000000000004, 0.4, 100.0]
# >>>> 	histogram: for (-100.0, 0.0): high_fractions =
# []
# >>>> 	histogram: for (0.0, 0.1): high_fractions =
# [0.8033129423091552,
#  0.3989127360176729,
#  0.7968961339989968,
#  0.40049475836631515,
#  0.004631170317631097,
#  0.3969144989147933,
#  0.7991682325416161,
#  0.4001262044435853,
#  0.795852371502677]
# >>>> 	histogram: for (0.1, 0.2): high_fractions =
# [0.6007785132719048,
#  0.9976017163365888,
#  0.9951443541498733,
#  0.5972787419596589,
#  0.5999221943669225,
#  0.6010830563359526,
#  0.9976573679297687]
# >>>> 	histogram: for (0.2, 0.30000000000000004): high_fractions =
# [0.0014241810625612024,
#  0.0035661473299808386,
#  0.003764405780517509,
#  0.000521904519694971,
#  0.004060023024683444]
# >>>> 	histogram: for (0.30000000000000004, 0.4): high_fractions =
# [0.20347662905440994,
#  0.19802155081216916,
#  0.19562462639762918,
#  0.1958997397706836]
# >>>> 	histogram: for (0.4, 100.0): high_fractions =
# []
# image_histo =
# [((-100.0, 0.0), 0.0),
#  ((0.0, 0.1), 4.203690951587557),
#  ((0.1, 0.2), 6.406843104061773),
#  ((0.2, 0.30000000000000004), 10.376129282633231),
#  ((0.30000000000000004, 0.4), 3.2203141156825463),
#  ((0.4, 100.0), 0.7930225460348919)]
# bin sum = 25.0
# img_entropy = 1.3871389363782594
# dentropy = 1.715221409348544	updated entropy = 1.3871389363782594
# histogram: img (flattened) =
# [0.32034766300544104,
#  0.20014241820625614,
#  0.1600778514271905,
#  0.2003566148329981,
#  0.31980215518121696,
#  0.1997601717336589,
#  0.08033129433091551,
#  0.039891273701767295,
#  0.07968961349989968,
#  0.19951443551498735,
#  0.1597278742959659,
#  0.040049475936631516,
#  0.0004631171317631098,
#  0.03969144999147933,
#  0.15999221953669227,
#  0.20037644067805177,
#  0.0799168233541616,
#  0.040012620544358536,
#  0.0795852372502677,
#  0.20005219055196952,
#  0.31956246273976296,
#  0.20040600240246836,
#  0.16010830573359527,
#  0.1997657368929769,
#  0.3195899740770684]
# bins_at =
# [-100.0, 0.0, 0.1, 0.2, 0.30000000000000004, 0.4, 100.0]
# >>>> 	histogram: for (-100.0, 0.0): high_fractions =
# []
# >>>> 	histogram: for (0.0, 0.1): high_fractions =
# [0.8033129433091551,
#  0.39891273701767294,
#  0.7968961349989968,
#  0.4004947593663151,
#  0.0046311713176310975,
#  0.39691449991479333,
#  0.7991682335416159,
#  0.40012620544358535,
#  0.7958523725026769]
# >>>> 	histogram: for (0.1, 0.2): high_fractions =
# [0.6007785142719049,
#  0.9976017173365889,
#  0.9951443551498734,
#  0.597278742959659,
#  0.5999221953669226,
#  0.6010830573359527,
#  0.9976573689297688]
# >>>> 	histogram: for (0.2, 0.30000000000000004): high_fractions =
# [0.0014241820625612851,
#  0.0035661483299809214,
#  0.0037644067805175916,
#  0.0005219055196950537,
#  0.004060024024683527]
# >>>> 	histogram: for (0.30000000000000004, 0.4): high_fractions =
# [0.20347663005441002,
#  0.19802155181216924,
#  0.19562462739762926,
#  0.19589974077068367]
# >>>> 	histogram: for (0.4, 100.0): high_fractions =
# []
# image_histo =
# [((-100.0, 0.0), 0.0),
#  ((0.0, 0.1), 4.203690942587557),
#  ((0.1, 0.2), 6.406843106061771),
#  ((0.2, 0.30000000000000004), 10.376129284633231),
#  ((0.30000000000000004, 0.4), 3.2203141166825464),
#  ((0.4, 100.0), 0.7930225500348922)]
# bin sum = 24.999999999999993
# img_entropy = 1.3871389365497817
# dentropy = 1.7152215097972938	updated entropy = 1.3871389365497817
# histogram: img (flattened) =
# [0.32034766310544105,
#  0.20014241830625612,
#  0.16007785152719048,
#  0.20035661493299808,
#  0.31980215528121697,
#  0.19976017183365888,
#  0.08033129443091552,
#  0.039891273801767296,
#  0.07968961359989969,
#  0.19951443561498733,
#  0.1597278743959659,
#  0.04004947603663152,
#  0.00046311723176310977,
#  0.039691450091479334,
#  0.15999221963669225,
#  0.20037644077805175,
#  0.07991682345416161,
#  0.04001262064435854,
#  0.0795852373502677,
#  0.2000521906519695,
#  0.319562462839763,
#  0.20040600250246834,
#  0.16010830583359525,
#  0.19976573699297687,
#  0.3195899741770684]
# bins_at =
# [-100.0, 0.0, 0.1, 0.2, 0.30000000000000004, 0.4, 100.0]
# >>>> 	histogram: for (-100.0, 0.0): high_fractions =
# []
# >>>> 	histogram: for (0.0, 0.1): high_fractions =
# [0.8033129443091552,
#  0.39891273801767296,
#  0.7968961359989969,
#  0.40049476036631515,
#  0.004631172317631097,
#  0.3969145009147933,
#  0.799168234541616,
#  0.4001262064435854,
#  0.795852373502677]
# >>>> 	histogram: for (0.1, 0.2): high_fractions =
# [0.6007785152719047,
#  0.9976017183365887,
#  0.9951443561498732,
#  0.5972787439596589,
#  0.5999221963669223,
#  0.6010830583359524,
#  0.9976573699297686]
# >>>> 	histogram: for (0.2, 0.30000000000000004): high_fractions =
# [0.0014241830625610903,
#  0.0035661493299807266,
#  0.003764407780517397,
#  0.0005219065196948589,
#  0.004060025024683332]
# >>>> 	histogram: for (0.30000000000000004, 0.4): high_fractions =
# [0.2034766310544101,
#  0.19802155281216932,
#  0.19562462839762934,
#  0.19589974177068376]
# >>>> 	histogram: for (0.4, 100.0): high_fractions =
# []
# image_histo =
# [((-100.0, 0.0), 0.0),
#  ((0.0, 0.1), 4.203690933587557),
#  ((0.1, 0.2), 6.406843108061774),
#  ((0.2, 0.30000000000000004), 10.376129286633233),
#  ((0.30000000000000004, 0.4), 3.220314117682545),
#  ((0.4, 100.0), 0.7930225540348925)]
# bin sum = 25.0
# img_entropy = 1.3871389367213036
# dentropy = 1.7152213992556073	updated entropy = 1.3871389367213036
# histogram: img (flattened) =
# [0.32034766320544106,
#  0.20014241840625613,
#  0.1600778516271905,
#  0.2003566150329981,
#  0.319802155381217,
#  0.1997601719336589,
#  0.08033129453091552,
#  0.0398912739017673,
#  0.07968961369989969,
#  0.19951443571498734,
#  0.1597278744959659,
#  0.04004947613663152,
#  0.0004631173317631098,
#  0.039691450191479336,
#  0.15999221973669225,
#  0.20037644087805176,
#  0.0799168235541616,
#  0.04001262074435854,
#  0.0795852374502677,
#  0.2000521907519695,
#  0.319562462939763,
#  0.20040600260246835,
#  0.16010830593359526,
#  0.19976573709297687,
#  0.3195899742770684]
# bins_at =
# [-100.0, 0.0, 0.1, 0.2, 0.30000000000000004, 0.4, 100.0]
# >>>> 	histogram: for (-100.0, 0.0): high_fractions =
# []
# >>>> 	histogram: for (0.0, 0.1): high_fractions =
# [0.8033129453091551,
#  0.39891273901767293,
#  0.7968961369989969,
#  0.4004947613663152,
#  0.004631173317631097,
#  0.3969145019147933,
#  0.799168235541616,
#  0.40012620744358535,
#  0.795852374502677]
# >>>> 	histogram: for (0.1, 0.2): high_fractions =
# [0.6007785162719048,
#  0.9976017193365888,
#  0.9951443571498733,
#  0.5972787449596589,
#  0.5999221973669224,
#  0.6010830593359525,
#  0.9976573709297687]
# >>>> 	histogram: for (0.2, 0.30000000000000004): high_fractions =
# [0.001424184062561173,
#  0.0035661503299808093,
#  0.0037644087805174795,
#  0.0005219075196949417,
#  0.004060026024683415]
# >>>> 	histogram: for (0.30000000000000004, 0.4): high_fractions =
# [0.2034766320544102,
#  0.1980215538121694,
#  0.19562462939762942,
#  0.19589974277068384]
# >>>> 	histogram: for (0.4, 100.0): high_fractions =
# []
# image_histo =
# [((-100.0, 0.0), 0.0),
#  ((0.0, 0.1), 4.2036909245875576),
#  ((0.1, 0.2), 6.406843110061773),
#  ((0.2, 0.30000000000000004), 10.376129288633233),
#  ((0.30000000000000004, 0.4), 3.2203141186825452),
#  ((0.4, 100.0), 0.7930225580348929)]
# bin sum = 25.0
# img_entropy = 1.3871389368928257
# dentropy = 1.7152213948673742	updated entropy = 1.3871389368928257
# histogram: img (flattened) =
# [0.320347663305441,
#  0.20014241850625614,
#  0.1600778517271905,
#  0.2003566151329981,
#  0.31980215548121693,
#  0.1997601720336589,
#  0.08033129463091553,
#  0.03989127400176729,
#  0.0796896137998997,
#  0.19951443581498735,
#  0.1597278745959659,
#  0.040049476236631514,
#  0.0004631174317631098,
#  0.03969145029147933,
#  0.15999221983669226,
#  0.20037644097805177,
#  0.07991682365416161,
#  0.04001262084435853,
#  0.07958523755026771,
#  0.2000521908519695,
#  0.31956246303976293,
#  0.20040600270246836,
#  0.16010830603359527,
#  0.19976573719297688,
#  0.3195899743770684]
# bins_at =
# [-100.0, 0.0, 0.1, 0.2, 0.30000000000000004, 0.4, 100.0]
# >>>> 	histogram: for (-100.0, 0.0): high_fractions =
# []
# >>>> 	histogram: for (0.0, 0.1): high_fractions =
# [0.8033129463091552,
#  0.3989127400176729,
#  0.796896137998997,
#  0.4004947623663151,
#  0.004631174317631098,
#  0.3969145029147933,
#  0.7991682365416161,
#  0.4001262084435853,
#  0.7958523755026771]
# >>>> 	histogram: for (0.1, 0.2): high_fractions =
# [0.6007785172719049,
#  0.9976017203365889,
#  0.9951443581498733,
#  0.597278745959659,
#  0.5999221983669225,
#  0.6010830603359526,
#  0.9976573719297688]
# >>>> 	histogram: for (0.2, 0.30000000000000004): high_fractions =
# [0.0014241850625612558,
#  0.003566151329980892,
#  0.0037644097805175623,
#  0.0005219085196950244,
#  0.004060027024683497]
# >>>> 	histogram: for (0.30000000000000004, 0.4): high_fractions =
# [0.20347663305440972,
#  0.19802155481216893,
#  0.19562463039762895,
#  0.19589974377068337]
# >>>> 	histogram: for (0.4, 100.0): high_fractions =
# []
# image_histo =
# [((-100.0, 0.0), 0.0),
#  ((0.0, 0.1), 4.203690915587557),
#  ((0.1, 0.2), 6.4068431120617735),
#  ((0.2, 0.30000000000000004), 10.376129290633234),
#  ((0.30000000000000004, 0.4), 3.220314119682547),
#  ((0.4, 100.0), 0.793022562034891)]
# bin sum = 25.000000000000004
# img_entropy = 1.3871389370643479
# dentropy = 1.715221390844827	updated entropy = 1.3871389370643479
# histogram: img (flattened) =
# [0.320347663405441,
#  0.20014241860625614,
#  0.1600778518271905,
#  0.2003566152329981,
#  0.31980215558121694,
#  0.1997601721336589,
#  0.08033129473091552,
#  0.03989127410176729,
#  0.07968961389989969,
#  0.19951443591498735,
#  0.15972787469596592,
#  0.040049476336631515,
#  0.00046311753176310976,
#  0.03969145039147933,
#  0.15999221993669227,
#  0.20037644107805178,
#  0.0799168237541616,
#  0.040012620944358535,
#  0.0795852376502677,
#  0.20005219095196952,
#  0.31956246313976294,
#  0.20040600280246837,
#  0.16010830613359528,
#  0.1997657372929769,
#  0.3195899744770684]
# bins_at =
# [-100.0, 0.0, 0.1, 0.2, 0.30000000000000004, 0.4, 100.0]
# >>>> 	histogram: for (-100.0, 0.0): high_fractions =
# []
# >>>> 	histogram: for (0.0, 0.1): high_fractions =
# [0.8033129473091551,
#  0.39891274101767293,
#  0.7968961389989968,
#  0.4004947633663151,
#  0.004631175317631097,
#  0.39691450391479327,
#  0.799168237541616,
#  0.40012620944358535,
#  0.795852376502677]
# >>>> 	histogram: for (0.1, 0.2): high_fractions =
# [0.600778518271905,
#  0.997601721336589,
#  0.9951443591498734,
#  0.5972787469596591,
#  0.5999221993669226,
#  0.6010830613359527,
#  0.9976573729297689]
# >>>> 	histogram: for (0.2, 0.30000000000000004): high_fractions =
# [0.0014241860625613385,
#  0.003566152329980975,
#  0.003764410780517645,
#  0.0005219095196951071,
#  0.00406002802468358]
# >>>> 	histogram: for (0.30000000000000004, 0.4): high_fractions =
# [0.2034766340544098,
#  0.19802155581216901,
#  0.19562463139762903,
#  0.19589974477068345]
# >>>> 	histogram: for (0.4, 100.0): high_fractions =
# []
# image_histo =
# [((-100.0, 0.0), 0.0),
#  ((0.0, 0.1), 4.203690906587557),
#  ((0.1, 0.2), 6.406843114061772),
#  ((0.2, 0.30000000000000004), 10.376129292633234),
#  ((0.30000000000000004, 0.4), 3.220314120682547),
#  ((0.4, 100.0), 0.7930225660348913)]
# bin sum = 25.000000000000004
# img_entropy = 1.3871389372358698
# dentropy = 1.7152212983262416	updated entropy = 1.3871389372358698
# histogram: img (flattened) =
# [0.320347663505441,
#  0.20014241870625613,
#  0.16007785192719048,
#  0.2003566153329981,
#  0.31980215568121695,
#  0.19976017223365888,
#  0.08033129483091551,
#  0.039891274201767295,
#  0.07968961399989968,
#  0.19951443601498733,
#  0.1597278747959659,
#  0.040049476436631516,
#  0.0004631176317631098,
#  0.03969145049147933,
#  0.15999222003669225,
#  0.20037644117805176,
#  0.0799168238541616,
#  0.040012621044358536,
#  0.0795852377502677,
#  0.2000521910519695,
#  0.31956246323976295,
#  0.20040600290246835,
#  0.16010830623359526,
# ...
# >>>> 	histogram: for (0.2, 0.30000000000000004): high_fractions =
# [0.0014242520625612483,
#  0.0035662183299808845,
#  0.0037644767805175548,
#  0.0005219755196950169,
#  0.00406009402468349]
# >>>> 	histogram: for (0.30000000000000004, 0.4): high_fractions =
# [0.2034767000544097,
#  0.19802162181216892,
#  0.19562469739762894,
#  0.19589981077068336]
# >>>> 	histogram: for (0.4, 100.0): high_fractions =
# []
# image_histo =
# [((-100.0, 0.0), 0.0),
#  ((0.0, 0.1), 4.203690312587557),
#  ((0.1, 0.2), 6.406843246061774),
#  ((0.2, 0.30000000000000004), 10.376129424633232),
#  ((0.30000000000000004, 0.4), 3.220314186682547),
#  ((0.4, 100.0), 0.7930228300348909)]
# bin sum = 25.0
# img_entropy = 1.3871389485563257
# dentropy = 1.7152207859156148	updated entropy = 1.3871389485563257
# histogram: img (flattened) =
# [0.320347670105441,
#  0.20014242530625614,
#  0.1600778585271905,
#  0.2003566219329981,
#  0.31980216228121694,
#  0.1997601788336589,
#  0.08033130143091552,
#  0.03989128080176729,
#  0.07968962059989969,
#  0.19951444261498735,
#  0.15972788139596591,
#  0.040049483036631514,
#  0.00046312423176310977,
#  0.03969145709147933,
#  0.15999222663669227,
#  0.20037644777805177,
#  0.0799168304541616,
#  0.040012627644358534,
#  0.0795852443502677,
#  0.20005219765196952,
#  0.31956246983976294,
#  0.20040600950246837,
#  0.16010831283359528,
#  0.1997657439929769,
#  0.3195899811770684]
# bins_at =
# [-100.0, 0.0, 0.1, 0.2, 0.30000000000000004, 0.4, 100.0]
# >>>> 	histogram: for (-100.0, 0.0): high_fractions =
# []
# >>>> 	histogram: for (0.0, 0.1): high_fractions =
# [0.8033130143091551,
#  0.3989128080176729,
#  0.7968962059989968,
#  0.4004948303663151,
#  0.0046312423176310975,
#  0.39691457091479326,
#  0.799168304541616,
#  0.40012627644358534,
#  0.795852443502677]
# >>>> 	histogram: for (0.1, 0.2): high_fractions =
# [0.600778585271905,
#  0.997601788336589,
#  0.9951444261498734,
#  0.5972788139596591,
#  0.5999222663669226,
#  0.6010831283359527,
#  0.9976574399297689]
# >>>> 	histogram: for (0.2, 0.30000000000000004): high_fractions =
# [0.001424253062561331,
#  0.0035662193299809673,
#  0.0037644777805176375,
#  0.0005219765196950996,
#  0.004060095024683573]
# >>>> 	histogram: for (0.30000000000000004, 0.4): high_fractions =
# [0.2034767010544098,
#  0.198021622812169,
#  0.19562469839762903,
#  0.19589981177068344]
# >>>> 	histogram: for (0.4, 100.0): high_fractions =
# []
# image_histo =
# [((-100.0, 0.0), 0.0),
#  ((0.0, 0.1), 4.203690303587557),
#  ((0.1, 0.2), 6.406843248061772),
#  ((0.2, 0.30000000000000004), 10.376129426633232),
#  ((0.30000000000000004, 0.4), 3.220314187682547),
#  ((0.4, 100.0), 0.7930228340348913)]
# bin sum = 24.999999999999996
# img_entropy = 1.3871389487278476
# dentropy = 1.7152207673500124	updated entropy = 1.3871389487278476
# histogram: img (flattened) =
# [0.320347670205441,
#  0.20014242540625612,
#  0.16007785862719048,
#  0.2003566220329981,
#  0.31980216238121695,
#  0.19976017893365888,
#  0.08033130153091553,
#  0.039891280901767294,
#  0.0796896206998997,
#  0.19951444271498733,
#  0.1597278814959659,
#  0.040049483136631515,
#  0.00046312433176310975,
#  0.03969145719147933,
#  0.15999222673669225,
#  0.20037644787805176,
#  0.07991683055416161,
#  0.040012627744358535,
#  0.07958524445026771,
#  0.2000521977519695,
#  0.31956246993976295,
#  0.20040600960246835,
#  0.16010831293359526,
#  0.19976574409297687,
#  0.3195899812770684]
# bins_at =
# [-100.0, 0.0, 0.1, 0.2, 0.30000000000000004, 0.4, 100.0]
# >>>> 	histogram: for (-100.0, 0.0): high_fractions =
# []
# >>>> 	histogram: for (0.0, 0.1): high_fractions =
# [0.8033130153091552,
#  0.3989128090176729,
#  0.7968962069989969,
#  0.40049483136631514,
#  0.004631243317631097,
#  0.3969145719147933,
#  0.7991683055416161,
#  0.4001262774435853,
#  0.7958524445026771]
# >>>> 	histogram: for (0.1, 0.2): high_fractions =
# [0.6007785862719047,
#  0.9976017893365887,
#  0.9951444271498733,
#  0.5972788149596588,
#  0.5999222673669224,
#  0.6010831293359525,
#  0.9976574409297686]
# >>>> 	histogram: for (0.2, 0.30000000000000004): high_fractions =
# [0.0014242540625611362,
#  0.0035662203299807725,
#  0.0037644787805174427,
#  0.0005219775196949048,
#  0.004060096024683378]
# >>>> 	histogram: for (0.30000000000000004, 0.4): high_fractions =
# [0.20347670205440987,
#  0.1980216238121691,
#  0.1956246993976291,
#  0.19589981277068352]
# >>>> 	histogram: for (0.4, 100.0): high_fractions =
# []
# image_histo =
# [((-100.0, 0.0), 0.0),
#  ((0.0, 0.1), 4.203690294587558),
#  ((0.1, 0.2), 6.406843250061774),
#  ((0.2, 0.30000000000000004), 10.37612942863323),
#  ((0.30000000000000004, 0.4), 3.2203141886825457),
#  ((0.4, 100.0), 0.7930228380348916)]
# bin sum = 25.0
# img_entropy = 1.3871389488993695
# dentropy = 1.7152207491836702	updated entropy = 1.3871389488993695
# histogram: img (flattened) =
# [0.32034767030544103,
#  0.20014242550625613,
#  0.1600778587271905,
#  0.2003566221329981,
#  0.31980216248121696,
#  0.1997601790336589,
#  0.08033130163091552,
#  0.039891281001767295,
#  0.07968962079989969,
#  0.19951444281498734,
#  0.1597278815959659,
#  0.04004948323663152,
#  0.0004631244317631098,
#  0.03969145729147933,
#  0.15999222683669226,
#  0.20037644797805176,
#  0.07991683065416161,
#  0.040012627844358536,
#  0.0795852445502677,
#  0.2000521978519695,
#  0.31956247003976296,
#  0.20040600970246836,
#  0.16010831303359527,
#  0.19976574419297688,
#  0.3195899813770684]
# bins_at =
# [-100.0, 0.0, 0.1, 0.2, 0.30000000000000004, 0.4, 100.0]
# >>>> 	histogram: for (-100.0, 0.0): high_fractions =
# []
# >>>> 	histogram: for (0.0, 0.1): high_fractions =
# [0.8033130163091552,
#  0.3989128100176729,
#  0.7968962079989969,
#  0.40049483236631517,
#  0.004631244317631097,
#  0.3969145729147933,
#  0.7991683065416161,
#  0.40012627844358534,
#  0.795852445502677]
# >>>> 	histogram: for (0.1, 0.2): high_fractions =
# [0.6007785872719048,
#  0.9976017903365888,
#  0.9951444281498734,
#  0.5972788159596589,
#  0.5999222683669225,
#  0.6010831303359526,
#  0.9976574419297687]
# >>>> 	histogram: for (0.2, 0.30000000000000004): high_fractions =
# [0.001424255062561219,
#  0.003566221329980855,
#  0.0037644797805175254,
#  0.0005219785196949875,
#  0.0040600970246834605]
# >>>> 	histogram: for (0.30000000000000004, 0.4): high_fractions =
# [0.20347670305440996,
#  0.19802162481216917,
#  0.1956247003976292,
#  0.1958998137706836]
# >>>> 	histogram: for (0.4, 100.0): high_fractions =
# []
# image_histo =
# [((-100.0, 0.0), 0.0),
#  ((0.0, 0.1), 4.203690285587557),
#  ((0.1, 0.2), 6.406843252061773),
#  ((0.2, 0.30000000000000004), 10.376129430633231),
#  ((0.30000000000000004, 0.4), 3.220314189682546),
#  ((0.4, 100.0), 0.7930228420348919)]
# bin sum = 24.999999999999996
# img_entropy = 1.3871389490708919
# dentropy = 1.715220778647379	updated entropy = 1.3871389490708919
# histogram: img (flattened) =
# [0.32034767040544104,
#  0.20014242560625614,
#  0.1600778588271905,
#  0.2003566222329981,
#  0.31980216258121696,
#  0.1997601791336589,
#  0.08033130173091552,
#  0.0398912811017673,
#  0.07968962089989969,
#  0.19951444291498735,
#  0.1597278816959659,
#  0.04004948333663152,
#  0.00046312453176310976,
#  0.039691457391479334,
#  0.15999222693669227,
#  0.20037644807805177,
#  0.0799168307541616,
#  0.04001262794435854,
#  0.0795852446502677,
#  0.20005219795196952,
#  0.31956247013976297,
#  0.20040600980246837,
#  0.16010831313359528,
#  0.1997657442929769,
#  0.3195899814770684]
# bins_at =
# [-100.0, 0.0, 0.1, 0.2, 0.30000000000000004, 0.4, 100.0]
# >>>> 	histogram: for (-100.0, 0.0): high_fractions =
# []
# >>>> 	histogram: for (0.0, 0.1): high_fractions =
# [0.8033130173091552,
#  0.39891281101767295,
#  0.7968962089989968,
#  0.40049483336631514,
#  0.004631245317631098,
#  0.39691457391479334,
#  0.7991683075416159,
#  0.40012627944358536,
#  0.795852446502677]
# >>>> 	histogram: for (0.1, 0.2): high_fractions =
# [0.6007785882719049,
#  0.9976017913365889,
#  0.9951444291498734,
#  0.597278816959659,
#  0.5999222693669226,
#  0.6010831313359527,
#  0.9976574429297688]
# >>>> 	histogram: for (0.2, 0.30000000000000004): high_fractions =
# [0.0014242560625613017,
#  0.003566222329980938,
#  0.003764480780517608,
#  0.0005219795196950703,
#  0.004060098024683543]
# >>>> 	histogram: for (0.30000000000000004, 0.4): high_fractions =
# [0.20347670405441004,
#  0.19802162581216926,
#  0.19562470139762927,
#  0.1958998147706837]
# >>>> 	histogram: for (0.4, 100.0): high_fractions =
# []
# image_histo =
# [((-100.0, 0.0), 0.0),
#  ((0.0, 0.1), 4.203690276587557),
#  ((0.1, 0.2), 6.406843254061771),
#  ((0.2, 0.30000000000000004), 10.376129432633231),
#  ((0.30000000000000004, 0.4), 3.220314190682546),
#  ((0.4, 100.0), 0.7930228460348923)]
# bin sum = 24.999999999999996
# img_entropy = 1.3871389492424138
# dentropy = 1.7152207607445664	updated entropy = 1.3871389492424138
# histogram: img (flattened) =
# [0.32034767050544105,
#  0.20014242570625612,
#  0.16007785892719048,
#  0.20035662233299809,
#  0.319802162681217,
#  0.19976017923365888,
#  0.08033130183091552,
#  0.0398912812017673,
#  0.0796896209998997,
#  0.19951444301498733,
#  0.1597278817959659,
#  0.04004948343663152,
#  0.0004631246317631098,
#  0.039691457491479336,
#  0.15999222703669225,
#  0.20037644817805175,
#  0.07991683085416161,
#  0.04001262804435854,
#  0.07958524475026771,
#  0.2000521980519695,
#  0.319562470239763,
#  0.20040600990246835,
#  0.16010831323359526,
#  0.19976574439297687,
#  0.3195899815770684]
# bins_at =
# [-100.0, 0.0, 0.1, 0.2, 0.30000000000000004, 0.4, 100.0]
# >>>> 	histogram: for (-100.0, 0.0): high_fractions =
# []
# >>>> 	histogram: for (0.0, 0.1): high_fractions =
# [0.8033130183091552,
#  0.398912812017673,
#  0.7968962099989969,
#  0.40049483436631517,
#  0.004631246317631098,
#  0.3969145749147933,
#  0.799168308541616,
#  0.4001262804435854,
#  0.795852447502677]
# >>>> 	histogram: for (0.1, 0.2): high_fractions =
# [0.6007785892719048,
#  0.9976017923365887,
#  0.9951444301498732,
#  0.5972788179596589,
#  0.5999222703669224,
#  0.6010831323359525,
#  0.9976574439297686]
# >>>> 	histogram: for (0.2, 0.30000000000000004): high_fractions =
# [0.0014242570625611069,
#  0.003566223329980743,
#  0.0037644817805174134,
#  0.0005219805196948755,
#  0.004060099024683348]
# >>>> 	histogram: for (0.30000000000000004, 0.4): high_fractions =
# [0.20347670505441012,
#  0.19802162681216934,
#  0.19562470239762936,
#  0.19589981577068377]
# >>>> 	histogram: for (0.4, 100.0): high_fractions =
# []
# image_histo =
# [((-100.0, 0.0), 0.0),
#  ((0.0, 0.1), 4.2036902675875565),
#  ((0.1, 0.2), 6.406843256061773),
#  ((0.2, 0.30000000000000004), 10.376129434633231),
#  ((0.30000000000000004, 0.4), 3.2203141916825446),
#  ((0.4, 100.0), 0.7930228500348926)]
# bin sum = 24.999999999999996
# img_entropy = 1.3871389494139357
# dentropy = 1.7152207432147293	updated entropy = 1.3871389494139357
# histogram: img (flattened) =
# [0.32034767060544106,
#  0.20014242580625613,
#  0.1600778590271905,
#  0.2003566224329981,
#  0.319802162781217,
#  0.1997601793336589,
#  0.08033130193091552,
#  0.03989128130176729,
#  0.07968962109989969,
#  0.19951444311498734,
#  0.1597278818959659,
#  0.040049483536631514,
#  0.0004631247317631098,
#  0.03969145759147933,
#  0.15999222713669226,
#  0.20037644827805176,
#  0.0799168309541616,
#  0.040012628144358534,
#  0.0795852448502677,
#  0.2000521981519695,
#  0.319562470339763,
#  0.20040601000246835,
#  0.16010831333359526,
#  0.19976574449297688,
#  0.3195899816770684]
# bins_at =
# [-100.0, 0.0, 0.1, 0.2, 0.30000000000000004, 0.4, 100.0]
# >>>> 	histogram: for (-100.0, 0.0): high_fractions =
# []
# >>>> 	histogram: for (0.0, 0.1): high_fractions =
# [0.8033130193091551,
#  0.3989128130176729,
#  0.7968962109989969,
#  0.40049483536631514,
#  0.004631247317631097,
#  0.3969145759147933,
#  0.799168309541616,
#  0.4001262814435853,
#  0.795852448502677]
# >>>> 	histogram: for (0.1, 0.2): high_fractions =
# [0.6007785902719048,
#  0.9976017933365888,
#  0.9951444311498733,
#  0.597278818959659,
#  0.5999222713669224,
#  0.6010831333359525,
#  0.9976574449297687]
# >>>> 	histogram: for (0.2, 0.30000000000000004): high_fractions =
# [0.0014242580625611896,
#  0.003566224329980826,
#  0.003764482780517496,
#  0.0005219815196949582,
#  0.004060100024683431]
# >>>> 	histogram: for (0.30000000000000004, 0.4): high_fractions =
# [0.2034767060544102,
#  0.19802162781216942,
#  0.19562470339762944,
#  0.19589981677068385]
# >>>> 	histogram: for (0.4, 100.0): high_fractions =
# []
# image_histo =
# [((-100.0, 0.0), 0.0),
#  ((0.0, 0.1), 4.2036902585875575),
#  ((0.1, 0.2), 6.406843258061773),
#  ((0.2, 0.30000000000000004), 10.376129436633232),
#  ((0.30000000000000004, 0.4), 3.2203141926825447),
#  ((0.4, 100.0), 0.7930228540348929)]
# bin sum = 24.999999999999996
# img_entropy = 1.3871389495854576
# dentropy = 1.715220726046332	updated entropy = 1.3871389495854576
# histogram: img (flattened) =
# [0.320347670705441,
#  0.20014242590625614,
#  0.1600778591271905,
#  0.2003566225329981,
#  0.31980216288121693,
#  0.1997601794336589,
#  0.08033130203091553,
#  0.039891281401767294,
#  0.0796896211998997,
#  0.19951444321498735,
#  0.1597278819959659,
#  0.040049483636631515,
#  0.00046312483176310976,
#  0.03969145769147933,
#  0.15999222723669226,
#  0.20037644837805177,
#  0.07991683105416161,
#  0.040012628244358535,
#  0.07958524495026771,
#  0.20005219825196952,
#  0.31956247043976294,
#  0.20040601010246836,
#  0.16010831343359527,
#  0.19976574459297688,
#  0.3195899817770684]
# bins_at =
# [-100.0, 0.0, 0.1, 0.2, 0.30000000000000004, 0.4, 100.0]
# >>>> 	histogram: for (-100.0, 0.0): high_fractions =
# []
# >>>> 	histogram: for (0.0, 0.1): high_fractions =
# [0.8033130203091552,
#  0.3989128140176729,
#  0.796896211998997,
#  0.4004948363663151,
#  0.004631248317631097,
#  0.3969145769147933,
#  0.7991683105416161,
#  0.40012628244358533,
#  0.7958524495026771]
# >>>> 	histogram: for (0.1, 0.2): high_fractions =
# [0.6007785912719049,
#  0.9976017943365889,
#  0.9951444321498734,
#  0.597278819959659,
#  0.5999222723669225,
#  0.6010831343359526,
#  0.9976574459297688]
# >>>> 	histogram: for (0.2, 0.30000000000000004): high_fractions =
# [0.0014242590625612723,
#  0.0035662253299809086,
#  0.003764483780517579,
#  0.000521982519695041,
#  0.004060101024683514]
# >>>> 	histogram: for (0.30000000000000004, 0.4): high_fractions =
# [0.20347670705440973,
#  0.19802162881216895,
#  0.19562470439762897,
#  0.19589981777068338]
# >>>> 	histogram: for (0.4, 100.0): high_fractions =
# []
# image_histo =
# [((-100.0, 0.0), 0.0),
#  ((0.0, 0.1), 4.203690249587557),
#  ((0.1, 0.2), 6.406843260061773),
#  ((0.2, 0.30000000000000004), 10.376129438633232),
#  ((0.30000000000000004, 0.4), 3.220314193682547),
#  ((0.4, 100.0), 0.793022858034891)]
# bin sum = 25.0
# img_entropy = 1.3871389497569797
# dentropy = 1.715220731885923	updated entropy = 1.3871389497569797
# histogram: img (flattened) =
# [0.320347670805441,
#  0.20014242600625612,
#  0.16007785922719048,
#  0.20035662263299808,
#  0.31980216298121694,
#  0.19976017953365888,
#  0.08033130213091552,
#  0.039891281501767295,
#  0.07968962129989969,
#  0.19951444331498733,
#  0.1597278820959659,
#  0.040049483736631517,
#  0.0004631249317631098,
#  0.03969145779147933,
#  0.15999222733669224,
#  0.20037644847805175,
#  0.07991683115416161,
#  0.040012628344358536,
#  0.0795852450502677,
#  0.2000521983519695,
#  0.31956247053976294,
#  0.20040601020246834,
#  0.16010831353359525,
#  0.19976574469297687,
#  0.3195899818770684]
# bins_at =
# [-100.0, 0.0, 0.1, 0.2, 0.30000000000000004, 0.4, 100.0]
# >>>> 	histogram: for (-100.0, 0.0): high_fractions =
# []
# >>>> 	histogram: for (0.0, 0.1): high_fractions =
# [0.8033130213091552,
#  0.39891281501767295,
#  0.7968962129989968,
#  0.40049483736631514,
#  0.004631249317631097,
#  0.3969145779147933,
#  0.799168311541616,
#  0.40012628344358536,
#  0.7958524505026771]
# >>>> 	histogram: for (0.1, 0.2): high_fractions =
# [0.6007785922719047,
#  0.9976017953365887,
#  0.9951444331498732,
#  0.5972788209596588,
#  0.5999222733669224,
#  0.6010831353359525,
#  0.9976574469297685]
# >>>> 	histogram: for (0.2, 0.30000000000000004): high_fractions =
# [0.0014242600625610775,
#  0.003566226329980714,
#  0.003764484780517384,
#  0.0005219835196948461,
#  0.004060102024683319]
# >>>> 	histogram: for (0.30000000000000004, 0.4): high_fractions =
# [0.20347670805440982,
#  0.19802162981216903,
#  0.19562470539762905,
#  0.19589981877068346]
# >>>> 	histogram: for (0.4, 100.0): high_fractions =
# []
# image_histo =
# [((-100.0, 0.0), 0.0),
#  ((0.0, 0.1), 4.203690240587557),
#  ((0.1, 0.2), 6.406843262061774),
#  ((0.2, 0.30000000000000004), 10.37612944063323),
#  ((0.30000000000000004, 0.4), 3.2203141946825458),
#  ((0.4, 100.0), 0.7930228620348914)]
# bin sum = 24.999999999999996
# img_entropy = 1.3871389499285016
# dentropy = 1.7152207151787942	updated entropy = 1.3871389499285016

# %%
#test that a uniform image has entropy >>> pixel count
#test that a dirac image has entropy >>> ???
#test that a gaussian image has entropy >>> ???
#test that shifting pixel values for an image doesn't (significantly) change entropy, as bins get narrower
#test d_Entropy / d_GaussWidth > 0.0

print("initial img = "); pprint.pprint(sq_img)
for iter in range(100):
    dS_dPixels = num_grad(lambda v:(mean_pixel_value_for_img(v)-0.5)**2-entropy_for_img(v, bins_at, dump=False), sq_img)
    print("dS_dPixels = "); pprint.pprint(dS_dPixels)
    sq_img = list(map(lambda px_dS:px_dS[0]-((1e-1)*px_dS[1]),
                        zip(sq_img, dS_dPixels)))
    print("next img = "); pprint.pprint(sq_img)

if plot_img:
    plt.imshow([[sq_img[r*sz+c] for c in range(sz)] for r in range(sz)])
    plt.draw()
    input()

#optimize entropy from dirac
#optimize entropy from random
#optimize entropy of an arbitrary image
